# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns
plt.style.use('ggplot')

# %%
order = pd.read_csv('datathon_2026_round1/dataset/interim/csv_exports/orders_base.csv')

# %%
order_items = pd.read_csv('datathon_2026_round1/dataset/interim/csv_exports/order_items_base.csv')
# Out:
# C:\Users\hfake\AppData\Local\Temp\ipykernel_2368\1292588466.py:1: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   order_items = pd.read_csv('datathon_2026_round1/dataset/interim/csv_exports/order_items_base.csv')

# %%
order.dtypes
# Out:
# order_id           int64
# order_date        object
# customer_id        int64
# zip                int64
# order_status      object
# payment_method    object
# device_type       object
# order_source      object
# dtype: object

# %%
order_items.dtypes
# Out:
# order_id             int64
# product_id           int64
# quantity             int64
# discount_amount    float64
# promo_id            object
# promo_id_2          object
# unit_price         float64
# dtype: object

# %%
order['order_date'] = pd.to_datetime(order['order_date'])

# %%
order_items['order_id'].isnull().sum()
# Out:
# np.int64(0)

# %%
order = order.merge(
    order_items,
    left_on='order_id',
    right_on='order_id',
    how='left'
)

# %%
order
# Out:
#         order_id order_date  customer_id    zip order_status payment_method  \
# 0              1 2012-07-04        58578   1109    delivered    credit_card
# 1              2 2012-07-04        58621   1330     returned            cod
# 2              3 2012-07-04        58811   1473    delivered    credit_card
# 3              4 2012-07-04        59453   2360    delivered    credit_card
# 4              6 2012-07-06        57821   2886    delivered         paypal
# ...          ...        ...          ...    ...          ...            ...
# 714648    834372 2022-12-31        19490  33907    delivered    credit_card
# 714649    834377 2022-12-31        73046  37091    delivered    credit_card
# 714650    834387 2022-12-31       107723  80516    delivered    credit_card
# 714651    834392 2022-12-31       139431  93510    delivered         paypal
# 714652    834397 2022-12-31       136302  95678    delivered    credit_card
#
#        device_type    order_source  product_id  quantity  discount_amount  \
# 0          desktop     paid_search        2400         7              0.0
# 1           mobile     paid_search         609         7              0.0
# 2          desktop          direct         396         3              0.0
# 3          desktop        referral         635         5              0.0
# 4           mobile  email_campaign        1935         1              0.0
# ...            ...             ...         ...       ...              ...
# 714648      mobile  email_campaign         690         8              0.0
# 714649      mobile        referral        1995         7              0.0
# 714650      mobile  email_campaign        2331         8              0.0
# 714651     desktop          direct        1115         5              0.0
# 714652      tablet  organic_search        1118         1              0.0
#
#        promo_id promo_id_2  unit_price
# 0           NaN        NaN     1138.22
# 1           NaN        NaN    10166.25
# 2           NaN        NaN    11220.33
# 3           NaN        NaN    10639.25
# 4           NaN        NaN     1597.84
# ...         ...        ...         ...
# 714648      NaN        NaN     4473.92
# 714649      NaN        NaN     5250.79
# 714650      NaN        NaN     7389.06
# 714651      NaN        NaN     4767.33
# 714652      NaN        NaN     4716.75
#
# [714653 rows x 14 columns]

# %%
order = (
    order
    .groupby('order_date')
    .agg(
        Total_Orders=('order_id', 'nunique'),
        Total_Order_Items=('order_id', 'count')
    )
    .reset_index()
    .rename(columns={'order_date': 'date'})
)

# %%
order
# Out:
#            date  Total_Orders  Total_Order_Items
# 0    2012-07-04           162                174
# 1    2012-07-05            97                103
# 2    2012-07-06            93                 99
# 3    2012-07-07            73                 75
# 4    2012-07-08            88                 94
# ...         ...           ...                ...
# 3828 2022-12-27           108                125
# 3829 2022-12-28           164                192
# 3830 2022-12-29           143                159
# 3831 2022-12-30           106                116
# 3832 2022-12-31            74                 81
#
# [3833 rows x 3 columns]

# %%
order['order_id'].value_counts()
# Out:
# order_id
# 348761    5
# 594591    5
# 136178    4
# 221569    4
# 530368    4
#          ..
# 298938    1
# 298941    1
# 298942    1
# 298943    1
# 834397    1
# Name: count, Length: 646945, dtype: int64

# %%
order['order_id'].duplicated().sum()
# Out:
# np.int64(67708)

# %%
order.query('order_id == 348761')
# Out:
#         order_id order_date  customer_id    zip order_status payment_method  \
# 305768    348761 2015-12-26        71190  35405    delivered    credit_card
# 305769    348761 2015-12-26        71190  35405    delivered    credit_card
# 305770    348761 2015-12-26        71190  35405    delivered    credit_card
# 305771    348761 2015-12-26        71190  35405    delivered    credit_card
# 305772    348761 2015-12-26        71190  35405    delivered    credit_card
#
#        device_type order_source  product_id  quantity  discount_amount  \
# 305768      tablet  paid_search        1113         3           926.39
# 305769      tablet  paid_search        2224         6           751.79
# 305770      tablet  paid_search        2225         4           473.33
# 305771      tablet  paid_search        2254         4           469.58
# 305772      tablet  paid_search        2255         4           461.66
#
#           promo_id promo_id_2  unit_price
# 305768  PROMO-0014        NaN     1543.98
# 305769  PROMO-0014        NaN      626.49
# 305770  PROMO-0014        NaN      591.66
# 305771  PROMO-0014        NaN      586.97
# 305772  PROMO-0014        NaN      577.07

# %%
order['order_date'].value_counts()
# Out:
# order_date
# 2018-05-30    885
# 2018-05-31    835
# 2017-03-30    800
# 2014-04-29    782
# 2018-06-01    778
#              ...
# 2021-01-02     17
# 2021-03-02     15
# 2020-01-02     14
# 2013-03-02      9
# 2020-02-29      8
# Name: count, Length: 3833, dtype: int64

# %%
sales = pd.read_csv('datathon_2026_round1/dataset/interim/csv_exports/sales_base.csv')

# %%
sales['date'] = pd.to_datetime(sales['date'])

# %%
sales_order = sales.merge(
    order,
    on='date',
    how='left'
)

# %%
sales_order
# Out:
#            date     revenue        cogs  Total_Orders  Total_Order_Items
# 0    2012-07-04  5123547.94  3982991.19           162                174
# 1    2012-07-05  2751773.45  2150580.23            97                103
# 2    2012-07-06  3054029.42  2517632.84            93                 99
# 3    2012-07-07  2667930.94  2108246.62            73                 75
# 4    2012-07-08  2360851.90  1808622.79            88                 94
# ...         ...         ...         ...           ...                ...
# 3828 2022-12-27  2100553.66  2184872.24           108                125
# 3829 2022-12-28  3448729.20  3513621.00           164                192
# 3830 2022-12-29  3083944.33  3170787.10           143                159
# 3831 2022-12-30  2884668.76  3022292.15           106                116
# 3832 2022-12-31  2383037.48  2279288.13            74                 81
#
# [3833 rows x 5 columns]

# %%
plt.figure(figsize=(16,6))

fig, ax1 = plt.subplots(figsize=(16,6))

ax1.plot(
    sales_order['date'],
    sales_order['revenue'],
    label='Revenue',
    color='blue'
)

ax1.set_xlabel('Date')
ax1.set_ylabel('Revenue', color='blue')
ax1.tick_params(axis='y', labelcolor='blue')

ax2 = ax1.twinx()

ax2.plot(
    sales_order['date'],
    sales_order['Total_Orders'],
    label='Total Orders',
    color='green'
)

ax2.set_ylabel('Total Orders', color='green')
ax2.tick_params(axis='y', labelcolor='green')

plt.title(
    'Daily Revenue vs Total Orders',
    fontsize=16,
    fontweight='bold'
)

fig.tight_layout()
plt.savefig(
    'chart3_1.png',
    dpi=300,
    bbox_inches='tight'
)
plt.show()

# %%
sales_order['Revenue_30D'] = (
    sales_order['revenue']
    .rolling(window=30)
    .mean()
)

sales_order['Orders_30D'] = (
    sales_order['Total_Orders']
    .rolling(window=30)
    .mean()
)

fig, ax1 = plt.subplots(figsize=(16,6))

ax1.plot(
    sales_order['date'],
    sales_order['Revenue_30D'],
    label='Revenue 30D Trend',
    color='blue',
    linewidth=3
)

ax1.set_xlabel('Date')
ax1.set_ylabel('Revenue 30D', color='blue')
ax1.tick_params(axis='y', labelcolor='blue')

ax2 = ax1.twinx()

ax2.plot(
    sales_order['date'],
    sales_order['Orders_30D'],
    label='Orders 30D Trend',
    color='green',
    linewidth=3
)

ax2.set_ylabel('Total Orders 30D', color='green')
ax2.tick_params(axis='y', labelcolor='green')

plt.title(
    'Revenue vs Total Orders Trend (30-Day Rolling Mean)',
    fontsize=16,
    fontweight='bold'
)

fig.tight_layout()
plt.savefig(
    'chart3_2.png',
    dpi=300,
    bbox_inches='tight'
)
plt.show()
